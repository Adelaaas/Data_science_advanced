# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
test= pd.read_csv("/content/gdrive/MyDrive/ii/test_weather.csv")
train= pd.read_csv("/content/gdrive/MyDrive/ii/train_weather.csv")
print(train.isna().sum())
print(test.isna().sum())
# Out:
# Location             0
# MinTemp           1221
# MaxTemp           1031
# Rainfall          2728
# Evaporation      50544
# Sunshine         56175
# WindGustDir       8716
# WindGustSpeed     8661
# WindDir9am        8914
# WindDir3pm        3354
# WindSpeed9am      1519
# WindSpeed3pm      2345
# Humidity9am       2231
# Humidity3pm       3382
# Pressure9am      12635
# Pressure3pm      12602
# Cloud9am         46059
# Cloud3pm         48476
# Temp9am           1533
# Temp3pm           2656
# RainToday            0
# RainTomorrow         0
# dtype: int64
# Location            0
# MinTemp           132
# MaxTemp           123
# Rainfall          285
# Evaporation      5608
# Sunshine         6211
# WindGustDir       976
# WindGustSpeed     968
# WindDir9am        994
# WindDir3pm        395
# WindSpeed9am      176
# WindSpeed3pm      283
# Humidity9am       237
# Humidity3pm       401
# Pressure9am      1382
# Pressure3pm      1381
# Cloud9am         5134
# Cloud3pm         5391
# ...

# %%
train = train.drop('Evaporation', axis=1)
train = train.drop('Sunshine', axis=1)
train = train.drop('Cloud9am', axis=1)
train = train.drop('Cloud3pm', axis=1)

# %%
test = test.drop('Evaporation', axis=1)
test = test.drop('Sunshine', axis=1)
test = test.drop('Cloud9am', axis=1)
test = test.drop('Cloud3pm', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-114b9f6b2abb> in <module>()
# ----> 1 test = test.drop('Evaporation', axis=1)
#       2 test = test.drop('Sunshine', axis=1)
#       3 test = test.drop('Cloud9am', axis=1)
#       4 test = test.drop('Cloud3pm', axis=1)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# ...

# %%
train
# Out:
#              Location  MinTemp  MaxTemp  ...  Temp3pm RainToday  RainTomorrow
# 0            Brisbane     13.7     23.6  ...     22.3         0             0
# 1              Sydney     15.4     21.2  ...     20.7         1             1
# 2            Richmond     16.8     30.9  ...     30.0         0             0
# 3       NorfolkIsland     13.9     17.1  ...     15.8         0             0
# 4             Mildura     16.0     36.1  ...     34.9         0             0
# ...               ...      ...      ...  ...      ...       ...           ...
# 121868      GoldCoast     17.6     25.1  ...     24.2         0             0
# 121869       Adelaide     15.1     25.2  ...     24.6         0             0
# 121870    MountGinini     10.5     18.4  ...     15.9         1             1
# 121871       Adelaide     13.6     19.8  ...     18.9         1             1
# 121872        Walpole      6.9     15.9  ...     14.3         0             0
#
# [121873 rows x 18 columns]

# %%
test
# Out:
#             Location  MinTemp  MaxTemp  ...  Temp9am Temp3pm  RainToday
# 0         PearceRAAF     11.0     22.1  ...     14.7    20.7          0
# 1             Albury      5.6     20.7  ...     13.9    20.3          0
# 2              Cobar      9.5     18.4  ...     11.5    17.9          0
# 3             Albany     18.4     22.0  ...     20.7    21.4          0
# 4       MountGambier     10.4     20.7  ...     15.7    18.0          0
# ...              ...      ...      ...  ...      ...     ...        ...
# 13536  BadgerysCreek     13.1     26.7  ...     19.4    26.0          0
# 13537       Richmond     16.4     30.1  ...     21.6    29.7          0
# 13538          Uluru     22.9     32.9  ...     25.2    31.4          0
# 13539           Nhil     12.5     34.2  ...     21.1    31.3          0
# 13540       Canberra      1.1     13.1  ...      7.1    10.2          0
#
# [13541 rows x 17 columns]

# %%
train = pd.get_dummies(train, columns=['Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm'])
test = pd.get_dummies(test, columns=['Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm'])

# %%
train
# Out:
#         MinTemp  MaxTemp  ...  WindDir3pm_WNW  WindDir3pm_WSW
# 0          13.7     23.6  ...               0               0
# 1          15.4     21.2  ...               0               0
# 2          16.8     30.9  ...               0               0
# 3          13.9     17.1  ...               0               0
# 4          16.0     36.1  ...               0               0
# ...         ...      ...  ...             ...             ...
# 121868     17.6     25.1  ...               0               0
# 121869     15.1     25.2  ...               0               1
# 121870     10.5     18.4  ...               0               0
# 121871     13.6     19.8  ...               0               1
# 121872      6.9     15.9  ...               0               0
#
# [121873 rows x 111 columns]

# %%
test
# Out:
#        MinTemp  MaxTemp  Rainfall  ...  WindDir3pm_W  WindDir3pm_WNW  WindDir3pm_WSW
# 0         11.0     22.1       0.0  ...             0               0               0
# 1          5.6     20.7       0.0  ...             0               0               0
# 2          9.5     18.4       0.0  ...             0               0               0
# 3         18.4     22.0       0.0  ...             0               0               0
# 4         10.4     20.7       0.4  ...             0               0               0
# ...        ...      ...       ...  ...           ...             ...             ...
# 13536     13.1     26.7       0.2  ...             0               1               0
# 13537     16.4     30.1       0.0  ...             0               0               1
# 13538     22.9     32.9       0.0  ...             0               0               0
# 13539     12.5     34.2       0.0  ...             0               0               0
# ...

# %%
train = train.dropna()

# %%
test=test.fillna(test.mean())

# %%
y = train['RainTomorrow']
X = train.drop('RainTomorrow', axis=1)
X
# Out:
#         MinTemp  MaxTemp  ...  WindDir3pm_WNW  WindDir3pm_WSW
# 0          13.7     23.6  ...               0               0
# 1          15.4     21.2  ...               0               0
# 2          16.8     30.9  ...               0               0
# 3          13.9     17.1  ...               0               0
# 4          16.0     36.1  ...               0               0
# ...         ...      ...  ...             ...             ...
# 121867     13.2     21.7  ...               0               0
# 121868     17.6     25.1  ...               0               0
# 121869     15.1     25.2  ...               0               1
# 121871     13.6     19.8  ...               0               1
# 121872      6.9     15.9  ...               0               0
#
# [100987 rows x 110 columns]

# %%
test
# Out:
#        MinTemp  MaxTemp  Rainfall  ...  WindDir3pm_W  WindDir3pm_WNW  WindDir3pm_WSW
# 0         11.0     22.1       0.0  ...             0               0               0
# 1          5.6     20.7       0.0  ...             0               0               0
# 2          9.5     18.4       0.0  ...             0               0               0
# 3         18.4     22.0       0.0  ...             0               0               0
# 4         10.4     20.7       0.4  ...             0               0               0
# ...        ...      ...       ...  ...           ...             ...             ...
# 13536     13.1     26.7       0.2  ...             0               1               0
# 13537     16.4     30.1       0.0  ...             0               0               1
# 13538     22.9     32.9       0.0  ...             0               0               0
# 13539     12.5     34.2       0.0  ...             0               0               0
# ...

# %%
#Делаем масштабирование признаков: нормализацию и стандартизацию
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_st = scaler.fit_transform(X)
print(X_st)
print('###################'*5)
scaler = MinMaxScaler()
X_norm = scaler.fit_transform(X)
# Out:
# [[ 0.22934058  0.04206485 -0.27346766 ... -0.27651366 -0.25864178
#   -0.27072264]
#  [ 0.49752895 -0.30245746  6.93947372 ... -0.27651366 -0.25864178
#   -0.27072264]
#  [ 0.71838997  1.08998689 -0.15560914 ... -0.27651366 -0.25864178
#   -0.27072264]
#  ...
#  [ 0.45020159  0.27174639 -0.27346766 ... -0.27651366 -0.25864178
#    3.69381734]
#  [ 0.21356479 -0.50342881  0.03296449 ... -0.27651366 -0.25864178
#    3.69381734]
#  [-0.84341293 -1.06327757 -0.24989596 ... -0.27651366 -0.25864178
#   -0.27072264]]
# ###############################################################################################

# %%
##Дерево решений с обычными
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score

X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=1/3, random_state=42)
tree = DecisionTreeClassifier(criterion='gini', max_depth=4, random_state=1)

tree.fit(X_train, y_train)
y_pred_tree = tree.predict(X_test)

print("Accuracy:", accuracy_score(y_test,y_pred_tree))
print("Recall:", recall_score(y_test,y_pred_tree))
print("Precision:", precision_score(y_test,y_pred_tree))
# Out:
# Accuracy: 0.8408341502539881
# Recall: 0.4024024024024024
# Precision: 0.7505091649694501

# %%
#Дерево решений с нормализованными
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score

X_train,X_test,y_train,y_test = train_test_split(X_norm, y, test_size=1/3, random_state=42)
tree = DecisionTreeClassifier(criterion='gini', max_depth=4, random_state=1)

tree.fit(X_train, y_train)
y_pred_tree = tree.predict(X_test)

print("Accuracy:", accuracy_score(y_test,y_pred_tree))
print("Recall:", recall_score(y_test,y_pred_tree))
print("Precision:", precision_score(y_test,y_pred_tree))
# Out:
# Accuracy: 0.8408341502539881
# Recall: 0.4024024024024024
# Precision: 0.7505091649694501

# %%
#Дерево решений со стандартизированными
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score

X_train,X_test,y_train,y_test = train_test_split(X_st, y, test_size=1/3, random_state=42)
tree = DecisionTreeClassifier(criterion='gini', max_depth=4, random_state=1)

tree.fit(X_train, y_train)
y_pred_tree = tree.predict(X_test)

print("Accuracy:", accuracy_score(y_test,y_pred_tree))
print("Recall:", recall_score(y_test,y_pred_tree))
print("Precision:", precision_score(y_test,y_pred_tree))
# Out:
# Accuracy: 0.8408341502539881
# Recall: 0.4024024024024024
# Precision: 0.7505091649694501

# %%
from google.colab import files

# %%
y_pred_tree = tree.predict(test)

# %%
y = pd.DataFrame(y_pred_tree, columns=['RainTomorrow'])
y.reset_index(inplace=True)
y.to_csv('Sevastyanov.csv', index=False)
files.download("Sevastyanov.csv")

# %%
y
# Out:
#        index  RainTomorrow
# 0          0             0
# 1          1             0
# 2          2             0
# 3          3             0
# 4          4             0
# ...      ...           ...
# 13536  13536             0
# 13537  13537             0
# 13538  13538             0
# 13539  13539             0
# 13540  13540             1
#
# [13541 rows x 2 columns]
