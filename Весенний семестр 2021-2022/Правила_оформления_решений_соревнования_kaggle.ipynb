# %% [markdown]
# **1. Вначале каждого решения необходимо привести вывод о решаемой вами задачи.**
#
# **Например,**
#
# Данная задача - это задача обучения с учителем, а именно многоклассовая/бинарная классификация.
# Целевая переменная такая-то.
# В качестве признаков можно взять следующие колонки ...

# %% [markdown]
# **2. Каждая строчка решений должна содержать поясняющий комментарий**

# %%
# Удалим ненужны по таким то причинам столбец
df = df.drop(columns=['label'])

# %% [markdown]
# **3. Каждая задача должна содержать исследование данных и выводы по исследованию.**
#
# - размерность данных;
# - наличие или отсутствие пропусков и варианты работы с ними в вашем решении;
# - баланс данных и варианты решения дисбаланса если таковой имеется. Желательно приводить гистограммы распредения классов используя визуализацию;
# - наличие или отсутсвие категориальных признаков и варианты работы с ними в вашем решении;
# - типы переменных;

# %% [markdown]
# **4. Все шаги решения должны быть обоснованы и приведены причины почему выбран тот или иной метод**

# %%
# В качестве признаков взяли следующие колонки: 1, 2, 3, так как они являются наиболее значимыми признаками
# Или взяли все колонки в качестве признаков так как все важны и т.д
X = df[df['col1, col2, col2']]

# %%
# Например, перебор различных моделей машинного обучения
# Их сравнение
# Выбор наиболее подходящей модели исходя из полученных оценок

# Мною был выбран метод "Дерево решения", так как accuracy была самой высокой
# и т.д.

# %%
# Я использовал нормализацию данных потому что...
# Я решил разбивать текст на n-gramm по словам потому что...

# %% [markdown]
# **5. В конце каждого решения должен быть приведен вывод.**
#
# Например:
#
# 1. Такие низкие оценки получились потому что ... (плохие данные, дисбаланс, я не смог решить лучше и т.д.)
# 2. Такие высокие оценки получились потому что ... (я хорошо решил, хорош обработал данные, произошло переобучение алгоритма и т.д)
# 3. Улучшить решение можно следующим образом: применить кроссвалидацию, реализовать нейронную сеть, провести нормализацию и т.д. (но тут тогда надо сказать почему вы не применили эти улучшения)
