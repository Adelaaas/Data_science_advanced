# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9ef7c9a0-5839-4d68-9a76-f00f2eebe52f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9ef7c9a0-5839-4d68-9a76-f00f2eebe52f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test_airplanes.csv to test_airplanes.csv
# Saving train_airplanes.csv to train_airplanes.csv

# %%
import pandas as pd

test = pd.read_csv('test_airplanes.csv')
train = pd.read_csv('train_airplanes.csv')
test
# Out:
#      Unnamed: 0  index         0  ...        27        28        29
# 0             0    800  1.432238  ... -0.271966 -1.197476 -0.366255
# 1             1    801 -0.487362  ...  1.049596 -0.329357 -1.257669
# 2             2    802  0.962898  ... -1.145836 -0.370616 -0.481098
# 3             3    803 -1.065925  ...  0.676382  1.070216  0.645921
# 4             4    804  0.728761  ... -0.472584 -1.116276  0.095643
# ..          ...    ...       ...  ...       ...       ...       ...
# 195         195    995  0.846628  ...  0.308251 -0.004729 -0.228137
# 196         196    996 -1.360590  ...  1.437369  1.422854 -0.830343
# 197         197    997  0.165061  ... -1.188404 -1.117578  0.475218
# 198         198    998  0.063662  ... -0.512474 -1.756672 -1.366628
# 199         199    999 -1.981903  ... -0.255371  1.655625 -1.332702
#
# [200 rows x 32 columns]

# %%
train
# Out:
#      Unnamed: 0  index         0  ...        28        29  target
# 0             0      0 -0.492317  ...  0.455824 -0.840537       1
# 1             1      1 -0.008567  ... -1.588205 -0.644534       0
# 2             2      2  0.262494  ...  0.234760  0.082982       1
# 3             3      3 -1.804729  ... -0.285059  0.638533       1
# 4             4      4 -0.017279  ...  1.344927 -2.390142       1
# ..          ...    ...       ...  ...       ...       ...     ...
# 795         795    795  0.480216  ...  0.725734 -0.649755       0
# 796         796    796  0.857515  ...  0.206624 -1.724080       1
# 797         797    797  0.023109  ...  0.443686  0.380687       1
# 798         798    798  0.081947  ...  0.799944 -0.439192       1
# 799         799    799 -2.227888  ... -0.747710  1.665824       1
#
# [800 rows x 33 columns]

# %%
from sklearn.model_selection import train_test_split

X = train.drop(["target"], axis=1)
y = train["target"]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_st = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_st, y, test_size=1/3, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score


model = LogisticRegression()
model = model.fit(X_train, y_train)

y_pred = model.predict(X_test)

# %%
from sklearn.tree import DecisionTreeRegressor	

tree = DecisionTreeRegressor()	
tree.fit(X_train, y_train)

y_pred = tree.predict(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(random_state=42)
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

# %%
clf = RandomForestClassifier(random_state=42)
clf.fit(X, y)
test = test.drop(['Unnamed: 0', 'index'], axis=1)

# %%
ans = clf.predict(test)
y_test_pred = pd.DataFrame(ans, columns=['target'])
y_test_pred.reset_index(inplace=True)

y_test_pred
# Out:
#      index  target
# 0        0       0
# 1        1       0
# 2        2       1
# 3        3       1
# 4        4       1
# ..     ...     ...
# 195    195       1
# 196    196       0
# 197    197       0
# 198    198       1
# 199    199       0
#
# [200 rows x 2 columns]

# %%
y.to_csv('submition_test_Rasyuk.csv', index=False)
files.download('submition_test_Rasyuk.csv')
