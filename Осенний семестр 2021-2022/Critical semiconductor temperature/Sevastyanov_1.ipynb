# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
formula_test=pd.read_csv("/content/gdrive/MyDrive/ii/formula_test.csv")
formula_train=pd.read_csv("/content/gdrive/MyDrive/ii/formula_train.csv")
test= pd.read_csv("/content/gdrive/MyDrive/ii/test.csv")
train= pd.read_csv("/content/gdrive/MyDrive/ii/train.csv")
print(train.isna().sum())
print(test.isna().sum())
print(formula_train.isna().sum())
print(formula_test.isna().sum())
# Out:
# feature1                0
# feature2                0
# feature3                0
# feature4                0
# feature5                0
#                        ..
# feature78               0
# feature79               0
# feature80               0
# feature81               0
# critical_temperature    0
# Length: 82, dtype: int64
# feature1     0
# feature2     0
# feature3     0
# feature4     0
# feature5     0
#             ..
# feature77    0
# feature78    0
# feature79    0
# feature80    0
# feature81    0
# Length: 81, dtype: int64
# H                0
# He               0
# Li               0
# Be               0
# B                0
#                 ..
# Po               0
# At               0
# Rn               0
# critical_temp    0
# material         0
# Length: 88, dtype: int64
# H           0
# He          0
# Li          0
# Be          0
# B           0
#            ..
# Bi          0
# Po          0
# At          0
# Rn          0
# material    0
# ...

# %%
y = train['critical_temperature'].astype(float)
X = train.drop('critical_temperature', axis=1)
X
# Out:
#        feature1    feature2    feature3  ...  feature79  feature80  feature81
# 0             4   95.950150   87.221940  ...   1.400000   1.299038   1.135782
# 1             5   83.244760   59.224400  ...   0.933333   1.200000   1.019804
# 2             2   23.035850   26.647510  ...   3.300000   1.500000   1.374773
# 3             4   81.756699   79.833804  ...   1.920000   1.118034   1.198165
# 4             2   67.485250   69.699016  ...   0.375000   0.000000   0.000000
# ...         ...         ...         ...  ...        ...        ...        ...
# 16995         3   72.816957   57.907791  ...   0.857143   0.471405   0.451754
# 16996         6   70.527467   91.385775  ...   1.150000   1.247219   1.388344
# 16997         2  145.650000  181.314000  ...   4.800000   0.000000   0.000000
# 16998         4   91.808100   56.820735  ...   0.821681   0.433013   0.269042
# 16999         5   76.392968   79.861421  ...   1.985600   1.019804   1.196725
#
# [17000 rows x 81 columns]

# %%
from sklearn.model_selection import train_test_split
X = train.drop(['critical_temperature'], axis=1)
y = train['critical_temperature']

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=1/3)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
answers_pred = model.predict(X_train)

print(model.score(X_test, y_test))
# Out:
# 0.734647815813609

# %%
from google.colab import files
predictions = model.predict(test)
df1 = pd.DataFrame({'Index': [i for i in range(len(predictions))],'critical_temp': predictions})
df1.to_csv('Sevastyanov.csv', index=False)
files.download("Sevastyanov.csv")
