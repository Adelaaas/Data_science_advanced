# %%
from google.colab import files
k  = files.upload()
# Out:
#      <input type="file" id="files-c195248a-f947-4eb7-86d0-f3abdf34d751" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c195248a-f947-4eb7-86d0-f3abdf34d751">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train.csv to train.csv
# Saving test.csv to test.csv

# %%
import pandas as pd

df1 = pd.read_csv('train.csv')
df1
# Out:
#        feature1    feature2  ...  feature81  critical_temperature
# 0             4   95.950150  ...   1.135782                21.500
# 1             5   83.244760  ...   1.019804                62.000
# 2             2   23.035850  ...   1.374773                 0.290
# 3             4   81.756699  ...   1.198165                19.500
# 4             2   67.485250  ...   0.000000                 5.360
# ...         ...         ...  ...        ...                   ...
# 16995         3   72.816957  ...   0.451754                35.000
# 16996         6   70.527467  ...   1.388344                89.000
# 16997         2  145.650000  ...   0.000000                 0.584
# 16998         4   91.808100  ...   0.269042                45.000
# 16999         5   76.392968  ...   1.196725                13.500
#
# [17000 rows x 82 columns]

# %%
df1.isna().sum()
# Out:
# feature1                0
# feature2                0
# feature3                0
# feature4                0
# feature5                0
#                        ..
# feature78               0
# feature79               0
# feature80               0
# feature81               0
# critical_temperature    0
# Length: 82, dtype: int64

# %%
df2 = pd.read_csv('test.csv')
df2
# Out:
#       feature1    feature2    feature3  ...  feature79  feature80  feature81
# 0            5   82.324574   88.533544  ...   0.814286   0.489898   0.358466
# 1            4  115.438500   90.562624  ...   1.504000   1.414214   0.853567
# 2            4   92.290900   83.842290  ...   1.600000   1.581139   1.361286
# 3            5   72.324650   51.227894  ...   1.070000   0.489898   0.270099
# 4            4   90.142263   58.462879  ...   1.057143   1.000000   0.903508
# ...        ...         ...         ...  ...        ...        ...        ...
# 4258         4  108.439500  115.102200  ...   2.760000   1.089725   1.110675
# 4259         6  103.903967   59.200661  ...   1.013333   1.213352   0.991878
# 4260         3   15.708900   15.348990  ...   1.766667   0.816497   0.525991
# 4261         5  100.966814   72.804399  ...   2.127073   1.469694   1.366704
# 4262         3   86.196460   74.958186  ...   2.380000   1.247219   1.193643
#
# [4263 rows x 81 columns]

# %%
y = df1['critical_temperature'].astype(float)
X = df1.drop('critical_temperature', axis=1)
X
# Out:
#        feature1    feature2    feature3  ...  feature79  feature80  feature81
# 0             4   95.950150   87.221940  ...   1.400000   1.299038   1.135782
# 1             5   83.244760   59.224400  ...   0.933333   1.200000   1.019804
# 2             2   23.035850   26.647510  ...   3.300000   1.500000   1.374773
# 3             4   81.756699   79.833804  ...   1.920000   1.118034   1.198165
# 4             2   67.485250   69.699016  ...   0.375000   0.000000   0.000000
# ...         ...         ...         ...  ...        ...        ...        ...
# 16995         3   72.816957   57.907791  ...   0.857143   0.471405   0.451754
# 16996         6   70.527467   91.385775  ...   1.150000   1.247219   1.388344
# 16997         2  145.650000  181.314000  ...   4.800000   0.000000   0.000000
# 16998         4   91.808100   56.820735  ...   0.821681   0.433013   0.269042
# 16999         5   76.392968   79.861421  ...   1.985600   1.019804   1.196725
#
# [17000 rows x 81 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
answers_pred = model.predict(X_train)

print(model.score(X_test, y_test))
# Out:
# 0.734381299573763

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X = scaler.fit_transform(X)

print(model.score(X_test, y_test))
# Out:
# 0.734381299573763

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(X)

print(model.score(X_test, y_test))
# Out:
# 0.734381299573763

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(X_train, y_train)
print(model.score(X_test, y_test))
# Out:
# 0.8613634214506387

# %%
predictions = model.predict(df2)
y_test_pred = pd.DataFrame({'Index': [i for i in range(len(predictions))],'critical_temp': predictions})

# %%
y_test_pred.to_csv('submition_test_Rasyuk.csv', index=False)
files.download("submition_test_Rasyuk.csv")
